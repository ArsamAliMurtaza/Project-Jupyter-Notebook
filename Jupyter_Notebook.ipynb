# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio
#
# MUHAMMAD ARSAM ALI MURTAZA <br>
# Data Analyst
#
# <i> I am intersted in Data Science because firstly I like the overall function of it and secondly I want to upskill my self for being able to handle data when ever I have some interesting problem at hand. </i>
#
# ### The code will print the string , Hello World!

# %%
x= "Hello World"
print(x)

# %% [markdown]
# <ol>
# <li>First</li>
# <li>Second</li>
# <li>Third</li>
# </ol>
#
# __[https://www.google.com](Tap to open Google webpage)__
#
#
# <hr>
